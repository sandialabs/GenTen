# %% [markdown]
# # Python notebook demonstrating streaming OnlineGCP applied to synthetic Gaussian data
# Demonstrates results similar to those found in the paper Eric T. Phipps, Nicholas T. Johnson, and Tamara G. Kolda. 2023.
# Streaming Generalized Canonical Polyadic Tensor Decompositions. In Proceedings of the Platform for Advanced Scientific Computing Conference (PASC '23).
# [https://doi.org/10.1145/3592979.3593405](https://dl.acm.org/doi/10.1145/3592979.3593405).

# %% [markdown]
# ### Import needed modules
# Generally better performance is obtained on CPU architectures with OpenMP parallelism when pygenten is imported before pyttb/numpy.

# %%
import pygenten as gt
import pyttb as ttb
import numpy as np
import matplotlib.pyplot as plt
import copy as cpy

# %% [markdown]
# ### Define some utility functions
# SynGaussTensor creates a random low-rank tensor that is periodic in time with Gaussian noise

# %%
def t_slice(u,t):
    # take a slice of a ktensor from a given t index
    ut = u.copy()
    tmp = ut.factor_matrices[-1]
    tmp = np.reshape(tmp[t,:],(1,-1))
    ut.factor_matrices[-1] = tmp
    return ut

class SynGaussTensor:
    def __init__(self, shape, T, rank, noise):
        self.shape = shape
        self.T = T
        self.rank = rank
        self.noise = noise

        full_shape = self.shape + (T,)

        # construct underlying ktensor
        self.u_true = ttb.ktensor.from_function(np.random.random_sample, full_shape, rank)
        self.u_true.weights = np.random.random_sample(rank)
        self.u_true.normalize(None).redistribute(self.u_true.ndims-1) # normalize factor matrix columns and put all weight in time mode

        # construct full unperturbed tensor
        self.X = self.u_true.full()

        # time slice counter
        self.t = 0

    def draw(self):
        # reset counter based on period
        if self.t >= self.T:
            self.t = 0

        # get slice t of unperturbed data including a unit-length time-mode
        ind = [slice(None)]*self.X.ndims 
        ind[-1] = self.t
        Xt = self.X.data[tuple(ind)] # same as X[:,:,...,t]
        Xt = np.reshape(Xt,Xt.shape+(1,))
        Xt = ttb.tensor(Xt)

        # get slice t of corressponding ktensor
        ut = t_slice(self.u_true,self.t)

        # construct noise tensor for slice t
        Zt = ttb.tensor.from_function(np.random.standard_normal, self.shape+(1,))

        Xt += (self.noise*Xt.norm()/Zt.norm())*Zt

        # increment time counter
        self.t += 1

        return Xt,ut
    
def gaussian_reconstruction_error(u,X):
    # Compute reconstruction error between U and X for each time slice.
    # u is a ktensor
    # X is a list of tensor slices
    nt = u.shape[-1]
    r = np.zeros(nt)
    for t in range(nt):
        u_t = t_slice(u,t)
        r[t] = (u_t.full()-X[t]).norm()**2 / X[t].norm()**2
    return r

def compute_score(u, u_true):
    # Compute ktensor score for each slice
    nt = u.shape[-1]
    s = np.zeros(nt)
    for t in range(nt):
        u_t = t_slice(u,t)
        u_true_t = t_slice(u_true,t)
        score,_,_,_ = u_true_t.score(u_t)
        s[t] = score
    return s

def tensor_to_sptensor(X):
    # convert a dense tensor to sparse (same as X.to_sptensor(), but yields subs with 'C' order suitable for GenTen)
    idx = np.nonzero(np.ravel(X.data, order="F"))[0]
    subs = np.array(np.unravel_index(idx, X.shape, order="F"),order='F').transpose()
    vals = X.data[tuple(subs.T)][:, None]
    return ttb.sptensor(subs, vals, X.shape, copy=False)

# %% [markdown]
# ### Generate synthetic data

# %%
syn_noise = 0.2        # noise level
syn_rank = 20          # rank of underlying tensor
syn_shape = (300,300)  # spatial size of the tensor
syn_T = 200            # temporal period
num_time = syn_T       # number of time steps in the final tensor
num_warm = 10          # number of time steps used in the warm start
rank = syn_rank        # rank of the CP decomposition

# %%
# generate synthetic data
np.random.seed(13) # set seed so we always get the same tensor
syn = SynGaussTensor(syn_shape, syn_T, syn_rank, syn_noise)
all_data = np.zeros((*syn_shape,syn_T))
slices = []
u_true_slice = []
for t in range(num_time):
    data,ut = syn.draw()
    all_data[:,:,t] = data.data[:,:,0]
    slices.append(data)
    u_true_slice.append(ut)
X = ttb.tensor(all_data)
X0 = X[:,:,0:num_warm]

# %% [markdown]
# ### Generate warm start

# %%
u_init,_,_ = gt.cp_als(X0,rank=rank,mttkrp_method=gt.MttkrpPhan,tol=1e-6,maxiters=1000)#,init=u0)
u_init.normalize(None).redistribute(2) # normalize factor matrix columns and put all weight in time mode
reconstruction_init = gaussian_reconstruction_error(u_init,slices)
# Out:
# Warning:  dense tensor passed to make_gt_tensor() is not C or F-contiguous, so will be copied and reordered
#
# Dense tensor:
#   300 x 300 x 10 (900000 total entries)
#   1.3e+03 Frobenius norm
#
# Execution environment:
#   MPI grid: 1 x 1 x 1 processes (1 total)
#   Execution space: openmp (8 threads)
#
# CP-ALS:
#   CP Rank: 20
#   MTTKRP method: phan
#   Gram formulation: symmetric
#
# Iter   1: fit =  7.927179e-01 fitdelta =  2.1e-01
# Iter   2: fit =  7.990990e-01 fitdelta =  6.4e-03
# Iter   3: fit =  8.006759e-01 fitdelta =  1.6e-03
# Iter   4: fit =  8.014336e-01 fitdelta =  7.6e-04
# Iter   5: fit =  8.019094e-01 fitdelta =  4.8e-04
# Iter   6: fit =  8.022608e-01 fitdelta =  3.5e-04
# Iter   7: fit =  8.025453e-01 fitdelta =  2.8e-04
# Iter   8: fit =  8.027899e-01 fitdelta =  2.4e-04
# Iter   9: fit =  8.030074e-01 fitdelta =  2.2e-04
# Iter  10: fit =  8.032041e-01 fitdelta =  2.0e-04
# Iter  11: fit =  8.033840e-01 fitdelta =  1.8e-04
# Iter  12: fit =  8.035506e-01 fitdelta =  1.7e-04
# Iter  13: fit =  8.037064e-01 fitdelta =  1.6e-04
# Iter  14: fit =  8.038529e-01 fitdelta =  1.5e-04
# Iter  15: fit =  8.039902e-01 fitdelta =  1.4e-04
# Iter  16: fit =  8.041171e-01 fitdelta =  1.3e-04
# Iter  17: fit =  8.042324e-01 fitdelta =  1.2e-04
# Iter  18: fit =  8.043348e-01 fitdelta =  1.0e-04
# Iter  19: fit =  8.044243e-01 fitdelta =  9.0e-05
# Iter  20: fit =  8.045019e-01 fitdelta =  7.8e-05
# Iter  21: fit =  8.045692e-01 fitdelta =  6.7e-05
# Iter  22: fit =  8.046278e-01 fitdelta =  5.9e-05
# Iter  23: fit =  8.046796e-01 fitdelta =  5.2e-05
# Iter  24: fit =  8.047259e-01 fitdelta =  4.6e-05
# Iter  25: fit =  8.047678e-01 fitdelta =  4.2e-05
# Iter  26: fit =  8.048060e-01 fitdelta =  3.8e-05
# Iter  27: fit =  8.048415e-01 fitdelta =  3.5e-05
# Iter  28: fit =  8.048748e-01 fitdelta =  3.3e-05
# Iter  29: fit =  8.049065e-01 fitdelta =  3.2e-05
# Iter  30: fit =  8.049371e-01 fitdelta =  3.1e-05
# Iter  31: fit =  8.049671e-01 fitdelta =  3.0e-05
# Iter  32: fit =  8.049967e-01 fitdelta =  3.0e-05
# Iter  33: fit =  8.050261e-01 fitdelta =  2.9e-05
# Iter  34: fit =  8.050551e-01 fitdelta =  2.9e-05
# Iter  35: fit =  8.050836e-01 fitdelta =  2.9e-05
# Iter  36: fit =  8.051113e-01 fitdelta =  2.8e-05
# Iter  37: fit =  8.051375e-01 fitdelta =  2.6e-05
# Iter  38: fit =  8.051615e-01 fitdelta =  2.4e-05
# Iter  39: fit =  8.051826e-01 fitdelta =  2.1e-05
# Iter  40: fit =  8.052008e-01 fitdelta =  1.8e-05
# Iter  41: fit =  8.052164e-01 fitdelta =  1.6e-05
# Iter  42: fit =  8.052296e-01 fitdelta =  1.3e-05
# Iter  43: fit =  8.052408e-01 fitdelta =  1.1e-05
# Iter  44: fit =  8.052504e-01 fitdelta =  9.6e-06
# Iter  45: fit =  8.052586e-01 fitdelta =  8.2e-06
# Iter  46: fit =  8.052657e-01 fitdelta =  7.1e-06
# Iter  47: fit =  8.052719e-01 fitdelta =  6.2e-06
# Iter  48: fit =  8.052773e-01 fitdelta =  5.4e-06
# Iter  49: fit =  8.052821e-01 fitdelta =  4.8e-06
# Iter  50: fit =  8.052864e-01 fitdelta =  4.3e-06
# Iter  51: fit =  8.052904e-01 fitdelta =  3.9e-06
# Iter  52: fit =  8.052939e-01 fitdelta =  3.6e-06
# Iter  53: fit =  8.052972e-01 fitdelta =  3.3e-06
# Iter  54: fit =  8.053002e-01 fitdelta =  3.0e-06
# Iter  55: fit =  8.053031e-01 fitdelta =  2.8e-06
# Iter  56: fit =  8.053057e-01 fitdelta =  2.7e-06
# Iter  57: fit =  8.053083e-01 fitdelta =  2.5e-06
# Iter  58: fit =  8.053107e-01 fitdelta =  2.4e-06
# Iter  59: fit =  8.053130e-01 fitdelta =  2.3e-06
# Iter  60: fit =  8.053152e-01 fitdelta =  2.2e-06
# Iter  61: fit =  8.053174e-01 fitdelta =  2.2e-06
# Iter  62: fit =  8.053195e-01 fitdelta =  2.1e-06
# Iter  63: fit =  8.053215e-01 fitdelta =  2.0e-06
# Iter  64: fit =  8.053235e-01 fitdelta =  2.0e-06
# Iter  65: fit =  8.053254e-01 fitdelta =  2.0e-06
# Iter  66: fit =  8.053274e-01 fitdelta =  1.9e-06
# Iter  67: fit =  8.053292e-01 fitdelta =  1.9e-06
# Iter  68: fit =  8.053311e-01 fitdelta =  1.8e-06
# Iter  69: fit =  8.053329e-01 fitdelta =  1.8e-06
# Iter  70: fit =  8.053347e-01 fitdelta =  1.8e-06
# Iter  71: fit =  8.053364e-01 fitdelta =  1.8e-06
# Iter  72: fit =  8.053382e-01 fitdelta =  1.7e-06
# Iter  73: fit =  8.053399e-01 fitdelta =  1.7e-06
# Iter  74: fit =  8.053416e-01 fitdelta =  1.7e-06
# Iter  75: fit =  8.053432e-01 fitdelta =  1.7e-06
# Iter  76: fit =  8.053448e-01 fitdelta =  1.6e-06
# Iter  77: fit =  8.053465e-01 fitdelta =  1.6e-06
# Iter  78: fit =  8.053481e-01 fitdelta =  1.6e-06
# Iter  79: fit =  8.053496e-01 fitdelta =  1.6e-06
# Iter  80: fit =  8.053512e-01 fitdelta =  1.6e-06
# Iter  81: fit =  8.053528e-01 fitdelta =  1.6e-06
# Iter  82: fit =  8.053544e-01 fitdelta =  1.6e-06
# Iter  83: fit =  8.053559e-01 fitdelta =  1.6e-06
# Iter  84: fit =  8.053575e-01 fitdelta =  1.6e-06
# Iter  85: fit =  8.053591e-01 fitdelta =  1.6e-06
# Iter  86: fit =  8.053606e-01 fitdelta =  1.6e-06
# Iter  87: fit =  8.053622e-01 fitdelta =  1.6e-06
# Iter  88: fit =  8.053637e-01 fitdelta =  1.6e-06
# Iter  89: fit =  8.053653e-01 fitdelta =  1.5e-06
# Iter  90: fit =  8.053668e-01 fitdelta =  1.5e-06
# Iter  91: fit =  8.053683e-01 fitdelta =  1.5e-06
# Iter  92: fit =  8.053698e-01 fitdelta =  1.5e-06
# Iter  93: fit =  8.053714e-01 fitdelta =  1.5e-06
# Iter  94: fit =  8.053728e-01 fitdelta =  1.5e-06
# Iter  95: fit =  8.053743e-01 fitdelta =  1.5e-06
# Iter  96: fit =  8.053758e-01 fitdelta =  1.5e-06
# Iter  97: fit =  8.053773e-01 fitdelta =  1.5e-06
# Iter  98: fit =  8.053788e-01 fitdelta =  1.5e-06
# Iter  99: fit =  8.053802e-01 fitdelta =  1.5e-06
# Iter 100: fit =  8.053817e-01 fitdelta =  1.5e-06
# Iter 101: fit =  8.053832e-01 fitdelta =  1.5e-06
# Iter 102: fit =  8.053846e-01 fitdelta =  1.5e-06
# Iter 103: fit =  8.053861e-01 fitdelta =  1.5e-06
# Iter 104: fit =  8.053875e-01 fitdelta =  1.5e-06
# Iter 105: fit =  8.053890e-01 fitdelta =  1.4e-06
# Iter 106: fit =  8.053904e-01 fitdelta =  1.4e-06
# Iter 107: fit =  8.053918e-01 fitdelta =  1.4e-06
# Iter 108: fit =  8.053932e-01 fitdelta =  1.4e-06
# Iter 109: fit =  8.053946e-01 fitdelta =  1.4e-06
# Iter 110: fit =  8.053960e-01 fitdelta =  1.4e-06
# Iter 111: fit =  8.053973e-01 fitdelta =  1.3e-06
# Iter 112: fit =  8.053987e-01 fitdelta =  1.3e-06
# Iter 113: fit =  8.054000e-01 fitdelta =  1.3e-06
# Iter 114: fit =  8.054012e-01 fitdelta =  1.3e-06
# Iter 115: fit =  8.054024e-01 fitdelta =  1.2e-06
# Iter 116: fit =  8.054036e-01 fitdelta =  1.2e-06
# Iter 117: fit =  8.054048e-01 fitdelta =  1.1e-06
# Iter 118: fit =  8.054059e-01 fitdelta =  1.1e-06
# Iter 119: fit =  8.054069e-01 fitdelta =  1.1e-06
# Iter 120: fit =  8.054079e-01 fitdelta =  1.0e-06
# Iter 121: fit =  8.054089e-01 fitdelta =  9.7e-07
# Final fit =  8.054089e-01

# %% [markdown]
# ### Compute static cp decomposition

# %%
u_cp,_,_ = gt.cp_als(X,rank=rank,mttkrp_method=gt.MttkrpPhan,tol=1e-7,maxiters=1000)
reconstruction_cp_als = gaussian_reconstruction_error(u_cp,slices)
score_cp = compute_score(u_cp,syn.u_true)
syn.u_true.score(u_cp)[0]
# Out:
# Dense tensor:
#   300 x 300 x 200 (1.800000e+07 total entries)
#   5.9e+03 Frobenius norm
#
# Execution environment:
#   MPI grid: 1 x 1 x 1 processes (1 total)
#   Execution space: openmp (8 threads)
#
# CP-ALS:
#   CP Rank: 20
#   MTTKRP method: phan
#   Gram formulation: symmetric
#
# Iter   1: fit =  7.833972e-01 fitdelta =  2.1e-01
# Iter   2: fit =  7.931154e-01 fitdelta =  9.7e-03
# Iter   3: fit =  7.954842e-01 fitdelta =  2.4e-03
# Iter   4: fit =  7.971669e-01 fitdelta =  1.7e-03
# Iter   5: fit =  7.983982e-01 fitdelta =  1.2e-03
# Iter   6: fit =  7.993203e-01 fitdelta =  9.2e-04
# Iter   7: fit =  7.999543e-01 fitdelta =  6.3e-04
# Iter   8: fit =  8.004635e-01 fitdelta =  5.1e-04
# Iter   9: fit =  8.008748e-01 fitdelta =  4.1e-04
# Iter  10: fit =  8.012071e-01 fitdelta =  3.3e-04
# Iter  11: fit =  8.015172e-01 fitdelta =  3.1e-04
# Iter  12: fit =  8.018041e-01 fitdelta =  2.9e-04
# Iter  13: fit =  8.020233e-01 fitdelta =  2.2e-04
# Iter  14: fit =  8.022105e-01 fitdelta =  1.9e-04
# Iter  15: fit =  8.023741e-01 fitdelta =  1.6e-04
# Iter  16: fit =  8.025225e-01 fitdelta =  1.5e-04
# Iter  17: fit =  8.026590e-01 fitdelta =  1.4e-04
# Iter  18: fit =  8.027841e-01 fitdelta =  1.3e-04
# Iter  19: fit =  8.028977e-01 fitdelta =  1.1e-04
# Iter  20: fit =  8.029992e-01 fitdelta =  1.0e-04
# Iter  21: fit =  8.030886e-01 fitdelta =  8.9e-05
# Iter  22: fit =  8.031662e-01 fitdelta =  7.8e-05
# Iter  23: fit =  8.032333e-01 fitdelta =  6.7e-05
# Iter  24: fit =  8.032916e-01 fitdelta =  5.8e-05
# Iter  25: fit =  8.033430e-01 fitdelta =  5.1e-05
# Iter  26: fit =  8.033896e-01 fitdelta =  4.7e-05
# Iter  27: fit =  8.034338e-01 fitdelta =  4.4e-05
# Iter  28: fit =  8.034777e-01 fitdelta =  4.4e-05
# Iter  29: fit =  8.035203e-01 fitdelta =  4.3e-05
# Iter  30: fit =  8.035567e-01 fitdelta =  3.6e-05
# Iter  31: fit =  8.035881e-01 fitdelta =  3.1e-05
# Iter  32: fit =  8.036184e-01 fitdelta =  3.0e-05
# Iter  33: fit =  8.036484e-01 fitdelta =  3.0e-05
# Iter  34: fit =  8.036773e-01 fitdelta =  2.9e-05
# Iter  35: fit =  8.037038e-01 fitdelta =  2.6e-05
# Iter  36: fit =  8.037275e-01 fitdelta =  2.4e-05
# Iter  37: fit =  8.037490e-01 fitdelta =  2.1e-05
# Iter  38: fit =  8.037689e-01 fitdelta =  2.0e-05
# Iter  39: fit =  8.037880e-01 fitdelta =  1.9e-05
# Iter  40: fit =  8.038062e-01 fitdelta =  1.8e-05
# Iter  41: fit =  8.038222e-01 fitdelta =  1.6e-05
# Iter  42: fit =  8.038347e-01 fitdelta =  1.3e-05
# Iter  43: fit =  8.038443e-01 fitdelta =  9.5e-06
# Iter  44: fit =  8.038520e-01 fitdelta =  7.7e-06
# Iter  45: fit =  8.038586e-01 fitdelta =  6.5e-06
# Iter  46: fit =  8.038642e-01 fitdelta =  5.6e-06
# Iter  47: fit =  8.038690e-01 fitdelta =  4.9e-06
# Iter  48: fit =  8.038733e-01 fitdelta =  4.2e-06
# Iter  49: fit =  8.038770e-01 fitdelta =  3.7e-06
# Iter  50: fit =  8.038803e-01 fitdelta =  3.3e-06
# Iter  51: fit =  8.038832e-01 fitdelta =  2.9e-06
# Iter  52: fit =  8.038858e-01 fitdelta =  2.6e-06
# Iter  53: fit =  8.038881e-01 fitdelta =  2.3e-06
# Iter  54: fit =  8.038902e-01 fitdelta =  2.1e-06
# Iter  55: fit =  8.038921e-01 fitdelta =  1.9e-06
# Iter  56: fit =  8.038938e-01 fitdelta =  1.7e-06
# Iter  57: fit =  8.038954e-01 fitdelta =  1.6e-06
# Iter  58: fit =  8.038969e-01 fitdelta =  1.4e-06
# Iter  59: fit =  8.038982e-01 fitdelta =  1.3e-06
# Iter  60: fit =  8.038994e-01 fitdelta =  1.2e-06
# Iter  61: fit =  8.039005e-01 fitdelta =  1.1e-06
# Iter  62: fit =  8.039015e-01 fitdelta =  1.0e-06
# Iter  63: fit =  8.039025e-01 fitdelta =  9.6e-07
# Iter  64: fit =  8.039034e-01 fitdelta =  9.0e-07
# Iter  65: fit =  8.039042e-01 fitdelta =  8.4e-07
# Iter  66: fit =  8.039050e-01 fitdelta =  7.8e-07
# Iter  67: fit =  8.039058e-01 fitdelta =  7.4e-07
# Iter  68: fit =  8.039065e-01 fitdelta =  7.0e-07
# Iter  69: fit =  8.039071e-01 fitdelta =  6.6e-07
# Iter  70: fit =  8.039077e-01 fitdelta =  6.2e-07
# Iter  71: fit =  8.039083e-01 fitdelta =  5.9e-07
# Iter  72: fit =  8.039089e-01 fitdelta =  5.6e-07
# Iter  73: fit =  8.039094e-01 fitdelta =  5.4e-07
# Iter  74: fit =  8.039100e-01 fitdelta =  5.2e-07
# Iter  75: fit =  8.039104e-01 fitdelta =  4.9e-07
# Iter  76: fit =  8.039109e-01 fitdelta =  4.8e-07
# Iter  77: fit =  8.039114e-01 fitdelta =  4.6e-07
# Iter  78: fit =  8.039118e-01 fitdelta =  4.4e-07
# Iter  79: fit =  8.039123e-01 fitdelta =  4.3e-07
# Iter  80: fit =  8.039127e-01 fitdelta =  4.1e-07
# Iter  81: fit =  8.039131e-01 fitdelta =  4.0e-07
# Iter  82: fit =  8.039135e-01 fitdelta =  3.9e-07
# Iter  83: fit =  8.039138e-01 fitdelta =  3.8e-07
# Iter  84: fit =  8.039142e-01 fitdelta =  3.7e-07
# Iter  85: fit =  8.039146e-01 fitdelta =  3.7e-07
# Iter  86: fit =  8.039149e-01 fitdelta =  3.6e-07
# Iter  87: fit =  8.039153e-01 fitdelta =  3.5e-07
# Iter  88: fit =  8.039156e-01 fitdelta =  3.5e-07
# Iter  89: fit =  8.039160e-01 fitdelta =  3.4e-07
# Iter  90: fit =  8.039163e-01 fitdelta =  3.4e-07
# Iter  91: fit =  8.039167e-01 fitdelta =  3.4e-07
# Iter  92: fit =  8.039170e-01 fitdelta =  3.4e-07
# Iter  93: fit =  8.039173e-01 fitdelta =  3.4e-07
# Iter  94: fit =  8.039177e-01 fitdelta =  3.4e-07
# Iter  95: fit =  8.039180e-01 fitdelta =  3.4e-07
# Iter  96: fit =  8.039184e-01 fitdelta =  3.4e-07
# Iter  97: fit =  8.039187e-01 fitdelta =  3.5e-07
# Iter  98: fit =  8.039191e-01 fitdelta =  3.6e-07
# Iter  99: fit =  8.039194e-01 fitdelta =  3.7e-07
# Iter 100: fit =  8.039198e-01 fitdelta =  3.9e-07
# Iter 101: fit =  8.039203e-01 fitdelta =  4.1e-07
# Iter 102: fit =  8.039207e-01 fitdelta =  4.5e-07
# Iter 103: fit =  8.039212e-01 fitdelta =  4.9e-07
# Iter 104: fit =  8.039217e-01 fitdelta =  5.5e-07
# Iter 105: fit =  8.039224e-01 fitdelta =  6.2e-07
# Iter 106: fit =  8.039231e-01 fitdelta =  7.3e-07
# Iter 107: fit =  8.039239e-01 fitdelta =  8.6e-07
# Iter 108: fit =  8.039250e-01 fitdelta =  1.0e-06
# Iter 109: fit =  8.039261e-01 fitdelta =  1.1e-06
# Iter 110: fit =  8.039272e-01 fitdelta =  1.1e-06
# Iter 111: fit =  8.039281e-01 fitdelta =  8.9e-07
# Iter 112: fit =  8.039286e-01 fitdelta =  5.8e-07
# Iter 113: fit =  8.039290e-01 fitdelta =  3.3e-07
# Iter 114: fit =  8.039292e-01 fitdelta =  2.0e-07
# Iter 115: fit =  8.039293e-01 fitdelta =  1.4e-07
# Iter 116: fit =  8.039294e-01 fitdelta =  1.2e-07
# Iter 117: fit =  8.039295e-01 fitdelta =  1.0e-07
# Iter 118: fit =  8.039296e-01 fitdelta =  9.7e-08
# Final fit =  8.039296e-01
# np.float64(0.852077357365333)

# %% [markdown]
# ### Compute static GCP decomposition

# %%
gcp_params = dict()
gcp_params['type'] = 'gaussian'
gcp_params['sampling'] = 'uniform'
gcp_params['fnzs'] = 100000
gcp_params['gnzs'] = 100000
gcp_params['hash'] = True
gcp_params['fuse'] = True
gcp_params['maxiters'] = 100
gcp_params['fails'] = 2
gcp_params['fit'] = True
u_static_gcp,_,_ = gt.gcp_sgd(X,rank=rank,**gcp_params)
reconstruction_static_gcp = gaussian_reconstruction_error(u_static_gcp,slices)
score_static_gcp = compute_score(u_static_gcp,syn.u_true)
syn.u_true.score(u_static_gcp)[0]
# Out:
# Dense tensor:
#   300 x 300 x 200 (1.800000e+07 total entries)
#   5.9e+03 Frobenius norm
#
# Execution environment:
#   MPI grid: 1 x 1 x 1 processes (1 total)
#   Execution space: openmp (8 threads)
#
# GCP-SGD (Generalized CP Tensor Decomposition):
# Generalized function type: Gaussian (normal)
# Optimization method: adam
# Max iterations (epochs): 100
# Iterations per epoch: 1000
# Traditional annealer, learning rate: 1.0e-03, decay: 1.0e-01
#   Function sampler:  uniform with 100000 samples
#   Gradient sampler:  uniform with 100000 samples
#   Gradient samples per epoch: 100000000 (555.6%)
# Gradient method: Fused sampling and duplicated MTTKRP
#
# Initial f-est:  6.373033e+06, fit:  5.746e-01, tensor norm:  5.932e+03
# Epoch   1: f-est =  1.673475e+06, fit =  7.807e-01, step =  1.0e-03, time = 3.74e+00 sec
# Epoch   2: f-est =  1.436881e+06, fit =  7.969e-01, step =  1.0e-03, time = 7.32e+00 sec
# Epoch   3: f-est =  1.392019e+06, fit =  8.003e-01, step =  1.0e-03, time = 1.09e+01 sec
# Epoch   4: f-est =  1.373987e+06, fit =  8.016e-01, step =  1.0e-03, time = 1.45e+01 sec
# Epoch   5: f-est =  1.363817e+06, fit =  8.023e-01, step =  1.0e-03, time = 1.81e+01 sec
# Epoch   6: f-est =  1.357254e+06, fit =  8.028e-01, step =  1.0e-03, time = 2.17e+01 sec
# Epoch   7: f-est =  1.352294e+06, fit =  8.032e-01, step =  1.0e-03, time = 2.53e+01 sec
# Epoch   8: f-est =  1.348602e+06, fit =  8.034e-01, step =  1.0e-03, time = 2.89e+01 sec
# Epoch   9: f-est =  1.346916e+06, fit =  8.036e-01, step =  1.0e-03, time = 3.25e+01 sec
# Epoch  10: f-est =  1.345596e+06, fit =  8.037e-01, step =  1.0e-03, time = 3.61e+01 sec
# Epoch  11: f-est =  1.343882e+06, fit =  8.037e-01, step =  1.0e-03, time = 3.97e+01 sec
# Epoch  12: f-est =  1.344845e+06, fit =  8.037e-01, step =  1.0e-03, time = 4.33e+01 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch  13: f-est =  1.342958e+06, fit =  8.038e-01, step =  1.0e-04, time = 4.69e+01 sec
# Epoch  14: f-est =  1.343030e+06, fit =  8.038e-01, step =  1.0e-04, time = 5.05e+01 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  15: f-est =  1.342899e+06, fit =  8.038e-01, step =  1.0e-05, time = 5.41e+01 sec
# Epoch  16: f-est =  1.342885e+06, fit =  8.038e-01, step =  1.0e-05, time = 5.77e+01 sec
# Epoch  17: f-est =  1.342905e+06, fit =  8.038e-01, step =  1.0e-05, time = 6.13e+01 sec, nfails = 3 (resetting to solution from last epoch)
# Final f-est:  1.342885e+06, fit:  8.038e-01
# GCP-SGD completed 17000 iterations in 6.13e+01 seconds
# np.float64(0.7593551756691367)

# %% [markdown]
# ### Compute streaming GCP decomposition

# %%
# temporal sgd solver params
temporal_params = dict()
temporal_params['sampling'] = 'uniform'
temporal_params['fnzs'] = 10000
temporal_params['gnzs'] = 10000
temporal_params['hash'] = True
temporal_params['fuse'] = True
temporal_params['maxiters'] = 20
temporal_params['fails'] = 3
temporal_params['epochiters'] = 10
temporal_params['rate'] = 10
temporal_params['fit'] = True
temporal_params['gcp-tol'] = 1e-5

# spatial sgd solver params
spatial_params = cpy.deepcopy(temporal_params)
spatial_params['maxiters'] = 5
spatial_params['rate'] = 1e-4

# streaming solver params
gcp_params = dict()
gcp_params['streaming-solver'] = 'sgd'
gcp_params['type'] = 'gaussian'
gcp_params['rank'] = rank
gcp_params['window-size'] = 50
gcp_params['window-method'] = 'reservoir'
gcp_params['printitn'] = 10

# compute streaming gcp decomposition
u_gcp,fest,ften = gt.online_gcp(slices[num_warm:],X0,u_init,temporal_params,spatial_params,**gcp_params)
u_gcp.normalize(None).redistribute(2)
u_gcp.factor_matrices[-1] = np.vstack((u_init.factor_matrices[-1],u_gcp.factor_matrices[-1]))
global_reconstruction_gcp = gaussian_reconstruction_error(u_gcp,slices)
local_reconstruction_gcp = list(reconstruction_init) + [ f/s.norm()**2 for f,s in zip(ften,slices) ]
score_gcp = compute_score(u_gcp,syn.u_true)
syn.u_true.score(u_gcp)[0]
# Out:
# Warning:  dense tensor passed to make_gt_tensor() is not C or F-contiguous, so will be copied and reordered
# Warning:  factor matrix passed to make_gt_ktensor() is not F-contiguous, so will be copied and reordered
# Warning:  factor matrix passed to make_gt_ktensor() is not F-contiguous, so will be copied and reordered
# Warning:  factor matrix passed to make_gt_ktensor() is not F-contiguous, so will be copied and reordered
#
# Online-GCP (Online Generalized CP Tensor Decomposition)
#
# Rank: 20
# Generalized function type: Gaussian (normal)
# Streaming window size: 50 (reservoir), penalty: 1.00e+00 * ( 1.00e+00 )^(T-t)
#
# Processing slice 10 of 190
# Solving for temporal mode...
# Initial f-est:  1.303110e+04, fit:  7.298e-01, tensor norm:  4.207e+02
# Epoch   1: f-est =  7.510817e+03, fit =  7.938e-01, step =  1.0e+01, time = 7.15e-03 sec
# Epoch   2: f-est =  7.023527e+03, fit =  8.010e-01, step =  1.0e+01, time = 1.44e-02 sec
# Epoch   3: f-est =  6.975302e+03, fit =  8.017e-01, step =  1.0e+01, time = 2.09e-02 sec
# Epoch   4: f-est =  6.944933e+03, fit =  8.014e-01, step =  1.0e+01, time = 2.78e-02 sec
# Epoch   5: f-est =  6.998184e+03, fit =  8.009e-01, step =  1.0e+01, time = 3.44e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   6: f-est =  6.923459e+03, fit =  8.022e-01, step =  1.0e+00, time = 4.09e-02 sec
# Epoch   7: f-est =  6.890972e+03, fit =  8.026e-01, step =  1.0e+00, time = 4.84e-02 sec
# Epoch   8: f-est =  6.902241e+03, fit =  8.026e-01, step =  1.0e+00, time = 5.50e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch   9: f-est =  6.889034e+03, fit =  8.026e-01, step =  1.0e-01, time = 6.24e-02 sec
# Epoch  10: f-est =  6.888371e+03, fit =  8.027e-01, step =  1.0e-01, time = 6.88e-02 sec
# Epoch  11: f-est =  6.886614e+03, fit =  8.027e-01, step =  1.0e-01, time = 7.51e-02 sec
# Epoch  12: f-est =  6.885030e+03, fit =  8.027e-01, step =  1.0e-01, time = 8.25e-02 sec
# Epoch  13: f-est =  6.885612e+03, fit =  8.028e-01, step =  1.0e-01, time = 8.91e-02 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  14: f-est =  6.885071e+03, fit =  8.027e-01, step =  1.0e-02, time = 9.63e-02 sec, nfails = 4 (resetting to solution from last epoch)
# Updating spatial modes...
# Initial f-est:  6.828649e+03, fit:  8.027e-01, tensor norm:  4.207e+02
# Epoch   1: f-est =  6.824425e+03, fit =  8.030e-01, step =  1.0e-04, time = 1.31e-02 sec
# Epoch   2: f-est =  6.815626e+03, fit =  8.032e-01, step =  1.0e-04, time = 2.42e-02 sec
# Epoch   3: f-est =  6.808142e+03, fit =  8.033e-01, step =  1.0e-04, time = 3.64e-02 sec
# Epoch   4: f-est =  6.807183e+03, fit =  8.034e-01, step =  1.0e-04, time = 4.79e-02 sec
# Epoch   5: f-est =  6.806637e+03, fit =  8.035e-01, step =  1.0e-04, time = 5.90e-02 sec
#
# Processing slice 20 of 190
# Solving for temporal mode...
# Initial f-est:  4.527704e+04, fit:  5.648e-01, tensor norm:  4.880e+02
# Epoch   1: f-est =  1.640370e+04, fit =  7.387e-01, step =  1.0e+01, time = 6.98e-03 sec
# Epoch   2: f-est =  1.023632e+04, fit =  7.930e-01, step =  1.0e+01, time = 1.39e-02 sec
# Epoch   3: f-est =  9.422219e+03, fit =  8.012e-01, step =  1.0e+01, time = 2.01e-02 sec
# Epoch   4: f-est =  9.428137e+03, fit =  8.010e-01, step =  1.0e+01, time = 2.71e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   5: f-est =  9.404027e+03, fit =  8.014e-01, step =  1.0e+00, time = 3.37e-02 sec
# Epoch   6: f-est =  9.335617e+03, fit =  8.021e-01, step =  1.0e+00, time = 4.02e-02 sec
# Epoch   7: f-est =  9.301576e+03, fit =  8.024e-01, step =  1.0e+00, time = 4.70e-02 sec
# Epoch   8: f-est =  9.284271e+03, fit =  8.027e-01, step =  1.0e+00, time = 5.35e-02 sec
# Epoch   9: f-est =  9.262029e+03, fit =  8.029e-01, step =  1.0e+00, time = 6.04e-02 sec
# Epoch  10: f-est =  9.252402e+03, fit =  8.031e-01, step =  1.0e+00, time = 6.68e-02 sec
# Epoch  11: f-est =  9.254434e+03, fit =  8.031e-01, step =  1.0e+00, time = 7.31e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  12: f-est =  9.251243e+03, fit =  8.031e-01, step =  1.0e-01, time = 8.00e-02 sec
# Epoch  13: f-est =  9.250601e+03, fit =  8.031e-01, step =  1.0e-01, time = 8.61e-02 sec
# Epoch  14: f-est =  9.249881e+03, fit =  8.031e-01, step =  1.0e-01, time = 9.29e-02 sec
# Epoch  15: f-est =  9.249348e+03, fit =  8.032e-01, step =  1.0e-01, time = 9.91e-02 sec
# Epoch  16: f-est =  9.249050e+03, fit =  8.032e-01, step =  1.0e-01, time = 1.05e-01 sec
# Epoch  17: f-est =  9.248102e+03, fit =  8.032e-01, step =  1.0e-01, time = 1.12e-01 sec
# Epoch  18: f-est =  9.247395e+03, fit =  8.032e-01, step =  1.0e-01, time = 1.19e-01 sec
# Epoch  19: f-est =  9.246501e+03, fit =  8.032e-01, step =  1.0e-01, time = 1.26e-01 sec
# Epoch  20: f-est =  9.246069e+03, fit =  8.032e-01, step =  1.0e-01, time = 1.32e-01 sec
# Updating spatial modes...
# Initial f-est:  9.132264e+03, fit:  8.032e-01, tensor norm:  4.880e+02
# Epoch   1: f-est =  9.120099e+03, fit =  8.036e-01, step =  1.0e-04, time = 1.25e-02 sec
# Epoch   2: f-est =  9.112609e+03, fit =  8.038e-01, step =  1.0e-04, time = 2.31e-02 sec
# Epoch   3: f-est =  9.106575e+03, fit =  8.040e-01, step =  1.0e-04, time = 3.43e-02 sec
# Epoch   4: f-est =  9.104699e+03, fit =  8.041e-01, step =  1.0e-04, time = 4.58e-02 sec
# Epoch   5: f-est =  9.108662e+03, fit =  8.041e-01, step =  1.0e-04, time = 5.67e-02 sec, nfails = 1 (resetting to solution from last epoch)
#
# Processing slice 30 of 190
# Solving for temporal mode...
# Initial f-est:  1.078803e+04, fit:  7.598e-01, tensor norm:  4.373e+02
# Epoch   1: f-est =  8.969066e+03, fit =  7.828e-01, step =  1.0e+01, time = 7.46e-03 sec
# Epoch   2: f-est =  7.698744e+03, fit =  8.004e-01, step =  1.0e+01, time = 1.43e-02 sec
# Epoch   3: f-est =  7.720686e+03, fit =  8.005e-01, step =  1.0e+01, time = 2.04e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   4: f-est =  7.560980e+03, fit =  8.019e-01, step =  1.0e+00, time = 2.72e-02 sec
# Epoch   5: f-est =  7.507709e+03, fit =  8.027e-01, step =  1.0e+00, time = 3.36e-02 sec
# Epoch   6: f-est =  7.502237e+03, fit =  8.029e-01, step =  1.0e+00, time = 4.03e-02 sec
# Epoch   7: f-est =  7.472166e+03, fit =  8.032e-01, step =  1.0e+00, time = 4.69e-02 sec
# Epoch   8: f-est =  7.458117e+03, fit =  8.033e-01, step =  1.0e+00, time = 5.33e-02 sec
# Epoch   9: f-est =  7.441131e+03, fit =  8.034e-01, step =  1.0e+00, time = 5.99e-02 sec
# Epoch  10: f-est =  7.436656e+03, fit =  8.035e-01, step =  1.0e+00, time = 6.65e-02 sec
# Epoch  11: f-est =  7.434447e+03, fit =  8.035e-01, step =  1.0e+00, time = 7.30e-02 sec
# Epoch  12: f-est =  7.431582e+03, fit =  8.035e-01, step =  1.0e+00, time = 7.99e-02 sec
# Epoch  13: f-est =  7.435451e+03, fit =  8.034e-01, step =  1.0e+00, time = 8.62e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  14: f-est =  7.431415e+03, fit =  8.035e-01, step =  1.0e-01, time = 9.29e-02 sec
# Epoch  15: f-est =  7.432337e+03, fit =  8.035e-01, step =  1.0e-01, time = 9.94e-02 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  16: f-est =  7.431372e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.06e-01 sec
# Epoch  17: f-est =  7.431330e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.13e-01 sec
# Epoch  18: f-est =  7.431250e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.19e-01 sec
# Epoch  19: f-est =  7.431169e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.26e-01 sec
# Epoch  20: f-est =  7.431120e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.32e-01 sec
# Updating spatial modes...
# Initial f-est:  7.393476e+03, fit:  8.035e-01, tensor norm:  4.373e+02
# Epoch   1: f-est =  7.397352e+03, fit =  8.036e-01, step =  1.0e-04, time = 1.27e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   2: f-est =  7.391838e+03, fit =  8.035e-01, step =  1.0e-05, time = 2.38e-02 sec
# Epoch   3: f-est =  7.390448e+03, fit =  8.036e-01, step =  1.0e-05, time = 3.49e-02 sec
# Epoch   4: f-est =  7.388751e+03, fit =  8.036e-01, step =  1.0e-05, time = 4.61e-02 sec
# Epoch   5: f-est =  7.387225e+03, fit =  8.036e-01, step =  1.0e-05, time = 5.72e-02 sec
#
# Processing slice 40 of 190
# Solving for temporal mode...
# Initial f-est:  2.410586e+04, fit:  5.968e-01, tensor norm:  3.804e+02
# Epoch   1: f-est =  6.778844e+03, fit =  7.844e-01, step =  1.0e+01, time = 7.97e-03 sec
# Epoch   2: f-est =  5.754523e+03, fit =  8.009e-01, step =  1.0e+01, time = 1.65e-02 sec
# Epoch   3: f-est =  5.867987e+03, fit =  7.985e-01, step =  1.0e+01, time = 2.37e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   4: f-est =  5.733129e+03, fit =  8.011e-01, step =  1.0e+00, time = 3.15e-02 sec
# Epoch   5: f-est =  5.694528e+03, fit =  8.020e-01, step =  1.0e+00, time = 3.87e-02 sec
# Epoch   6: f-est =  5.669060e+03, fit =  8.024e-01, step =  1.0e+00, time = 4.67e-02 sec
# Epoch   7: f-est =  5.649028e+03, fit =  8.027e-01, step =  1.0e+00, time = 5.39e-02 sec
# Epoch   8: f-est =  5.643873e+03, fit =  8.029e-01, step =  1.0e+00, time = 6.12e-02 sec
# Epoch   9: f-est =  5.636296e+03, fit =  8.031e-01, step =  1.0e+00, time = 6.88e-02 sec
# Epoch  10: f-est =  5.633620e+03, fit =  8.031e-01, step =  1.0e+00, time = 7.62e-02 sec
# Epoch  11: f-est =  5.632425e+03, fit =  8.031e-01, step =  1.0e+00, time = 8.39e-02 sec
# Epoch  12: f-est =  5.631728e+03, fit =  8.031e-01, step =  1.0e+00, time = 9.15e-02 sec
# Epoch  13: f-est =  5.631860e+03, fit =  8.031e-01, step =  1.0e+00, time = 9.93e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  14: f-est =  5.630879e+03, fit =  8.032e-01, step =  1.0e-01, time = 1.10e-01 sec
# Epoch  15: f-est =  5.630400e+03, fit =  8.032e-01, step =  1.0e-01, time = 1.18e-01 sec
# Epoch  16: f-est =  5.630498e+03, fit =  8.032e-01, step =  1.0e-01, time = 1.26e-01 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  17: f-est =  5.630411e+03, fit =  8.032e-01, step =  1.0e-02, time = 1.33e-01 sec, nfails = 4 (resetting to solution from last epoch)
# Updating spatial modes...
# Initial f-est:  5.635664e+03, fit:  8.032e-01, tensor norm:  3.804e+02
# Epoch   1: f-est =  5.642572e+03, fit =  8.033e-01, step =  1.0e-04, time = 3.17e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   2: f-est =  5.634714e+03, fit =  8.032e-01, step =  1.0e-05, time = 4.29e-02 sec
# Epoch   3: f-est =  5.633151e+03, fit =  8.032e-01, step =  1.0e-05, time = 5.40e-02 sec
# Epoch   4: f-est =  5.631798e+03, fit =  8.033e-01, step =  1.0e-05, time = 6.53e-02 sec
# Epoch   5: f-est =  5.630716e+03, fit =  8.033e-01, step =  1.0e-05, time = 7.66e-02 sec
#
# Processing slice 50 of 190
# Solving for temporal mode...
# Initial f-est:  1.247380e+04, fit:  7.532e-01, tensor norm:  4.557e+02
# Epoch   1: f-est =  8.295690e+03, fit =  8.007e-01, step =  1.0e+01, time = 7.03e-03 sec
# Epoch   2: f-est =  8.332609e+03, fit =  8.001e-01, step =  1.0e+01, time = 1.39e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   3: f-est =  8.143419e+03, fit =  8.024e-01, step =  1.0e+00, time = 2.05e-02 sec
# Epoch   4: f-est =  8.120499e+03, fit =  8.028e-01, step =  1.0e+00, time = 2.74e-02 sec
# Epoch   5: f-est =  8.091695e+03, fit =  8.031e-01, step =  1.0e+00, time = 3.38e-02 sec
# Epoch   6: f-est =  8.082072e+03, fit =  8.032e-01, step =  1.0e+00, time = 4.04e-02 sec
# Epoch   7: f-est =  8.058813e+03, fit =  8.034e-01, step =  1.0e+00, time = 4.69e-02 sec
# Epoch   8: f-est =  8.060604e+03, fit =  8.034e-01, step =  1.0e+00, time = 5.37e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch   9: f-est =  8.058507e+03, fit =  8.034e-01, step =  1.0e-01, time = 6.01e-02 sec
# Epoch  10: f-est =  8.058080e+03, fit =  8.034e-01, step =  1.0e-01, time = 6.66e-02 sec
# Epoch  11: f-est =  8.058535e+03, fit =  8.034e-01, step =  1.0e-01, time = 7.30e-02 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  12: f-est =  8.058071e+03, fit =  8.034e-01, step =  1.0e-02, time = 7.99e-02 sec
# Epoch  13: f-est =  8.058087e+03, fit =  8.034e-01, step =  1.0e-02, time = 8.66e-02 sec, nfails = 4 (resetting to solution from last epoch)
# Updating spatial modes...
# Initial f-est:  8.166958e+03, fit:  8.034e-01, tensor norm:  4.557e+02
# Epoch   1: f-est =  8.168281e+03, fit =  8.036e-01, step =  1.0e-04, time = 1.30e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   2: f-est =  8.165552e+03, fit =  8.034e-01, step =  1.0e-05, time = 2.39e-02 sec
# Epoch   3: f-est =  8.162096e+03, fit =  8.035e-01, step =  1.0e-05, time = 3.55e-02 sec
# Epoch   4: f-est =  8.159131e+03, fit =  8.035e-01, step =  1.0e-05, time = 4.71e-02 sec
# Epoch   5: f-est =  8.156922e+03, fit =  8.036e-01, step =  1.0e-05, time = 5.80e-02 sec
#
# Processing slice 60 of 190
# Solving for temporal mode...
# Initial f-est:  1.589786e+04, fit:  6.612e-01, tensor norm:  3.677e+02
# Epoch   1: f-est =  6.548155e+03, fit =  7.798e-01, step =  1.0e+01, time = 7.06e-03 sec
# Epoch   2: f-est =  5.636029e+03, fit =  7.960e-01, step =  1.0e+01, time = 1.39e-02 sec
# Epoch   3: f-est =  5.583320e+03, fit =  7.975e-01, step =  1.0e+01, time = 2.04e-02 sec
# Epoch   4: f-est =  5.357533e+03, fit =  8.018e-01, step =  1.0e+01, time = 2.74e-02 sec
# Epoch   5: f-est =  5.339348e+03, fit =  8.017e-01, step =  1.0e+01, time = 3.36e-02 sec
# Epoch   6: f-est =  5.291203e+03, fit =  8.028e-01, step =  1.0e+01, time = 4.05e-02 sec
# Epoch   7: f-est =  5.346183e+03, fit =  8.022e-01, step =  1.0e+01, time = 4.66e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   8: f-est =  5.288718e+03, fit =  8.029e-01, step =  1.0e+00, time = 5.31e-02 sec
# Epoch   9: f-est =  5.283622e+03, fit =  8.030e-01, step =  1.0e+00, time = 5.97e-02 sec
# Epoch  10: f-est =  5.281387e+03, fit =  8.030e-01, step =  1.0e+00, time = 6.62e-02 sec
# Epoch  11: f-est =  5.279656e+03, fit =  8.030e-01, step =  1.0e+00, time = 7.28e-02 sec
# Epoch  12: f-est =  5.278180e+03, fit =  8.030e-01, step =  1.0e+00, time = 7.91e-02 sec
# Epoch  13: f-est =  5.280211e+03, fit =  8.030e-01, step =  1.0e+00, time = 8.55e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  14: f-est =  5.277949e+03, fit =  8.030e-01, step =  1.0e-01, time = 9.21e-02 sec
# Epoch  15: f-est =  5.277924e+03, fit =  8.030e-01, step =  1.0e-01, time = 9.84e-02 sec
# Epoch  16: f-est =  5.277883e+03, fit =  8.030e-01, step =  1.0e-01, time = 1.05e-01 sec
# Epoch  17: f-est =  5.277848e+03, fit =  8.030e-01, step =  1.0e-01, time = 1.12e-01 sec
# Epoch  18: f-est =  5.278056e+03, fit =  8.031e-01, step =  1.0e-01, time = 1.18e-01 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  19: f-est =  5.277884e+03, fit =  8.030e-01, step =  1.0e-02, time = 1.25e-01 sec, nfails = 4 (resetting to solution from last epoch)
# Updating spatial modes...
# Initial f-est:  5.221732e+03, fit:  8.030e-01, tensor norm:  3.677e+02
# Epoch   1: f-est =  5.223921e+03, fit =  8.032e-01, step =  1.0e-04, time = 1.29e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   2: f-est =  5.220772e+03, fit =  8.031e-01, step =  1.0e-05, time = 2.36e-02 sec
# Epoch   3: f-est =  5.219314e+03, fit =  8.031e-01, step =  1.0e-05, time = 3.50e-02 sec
# Epoch   4: f-est =  5.217826e+03, fit =  8.032e-01, step =  1.0e-05, time = 4.60e-02 sec
# Epoch   5: f-est =  5.216507e+03, fit =  8.032e-01, step =  1.0e-05, time = 5.73e-02 sec
#
# Processing slice 70 of 190
# Solving for temporal mode...
# Initial f-est:  2.691298e+04, fit:  5.507e-01, tensor norm:  3.644e+02
# Epoch   1: f-est =  6.527017e+03, fit =  7.773e-01, step =  1.0e+01, time = 8.11e-03 sec
# Epoch   2: f-est =  5.729458e+03, fit =  7.912e-01, step =  1.0e+01, time = 1.59e-02 sec
# Epoch   3: f-est =  5.600051e+03, fit =  7.936e-01, step =  1.0e+01, time = 2.35e-02 sec
# Epoch   4: f-est =  5.328394e+03, fit =  7.986e-01, step =  1.0e+01, time = 3.12e-02 sec
# Epoch   5: f-est =  5.155375e+03, fit =  8.021e-01, step =  1.0e+01, time = 3.89e-02 sec
# Epoch   6: f-est =  5.105460e+03, fit =  8.029e-01, step =  1.0e+01, time = 4.63e-02 sec
# Epoch   7: f-est =  5.096758e+03, fit =  8.029e-01, step =  1.0e+01, time = 5.35e-02 sec
# Epoch   8: f-est =  5.135522e+03, fit =  8.024e-01, step =  1.0e+01, time = 6.18e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   9: f-est =  5.091593e+03, fit =  8.030e-01, step =  1.0e+00, time = 6.90e-02 sec
# Epoch  10: f-est =  5.091942e+03, fit =  8.031e-01, step =  1.0e+00, time = 7.70e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  11: f-est =  5.091730e+03, fit =  8.030e-01, step =  1.0e-01, time = 8.42e-02 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  12: f-est =  5.091591e+03, fit =  8.030e-01, step =  1.0e-02, time = 9.21e-02 sec
# Epoch  13: f-est =  5.091538e+03, fit =  8.030e-01, step =  1.0e-02, time = 9.95e-02 sec
# Epoch  14: f-est =  5.091454e+03, fit =  8.030e-01, step =  1.0e-02, time = 1.07e-01 sec
# Epoch  15: f-est =  5.091343e+03, fit =  8.030e-01, step =  1.0e-02, time = 1.15e-01 sec
# Epoch  16: f-est =  5.091279e+03, fit =  8.030e-01, step =  1.0e-02, time = 1.23e-01 sec
# Epoch  17: f-est =  5.091163e+03, fit =  8.030e-01, step =  1.0e-02, time = 1.30e-01 sec
# Epoch  18: f-est =  5.091033e+03, fit =  8.030e-01, step =  1.0e-02, time = 1.38e-01 sec
# Epoch  19: f-est =  5.090907e+03, fit =  8.030e-01, step =  1.0e-02, time = 1.46e-01 sec
# Epoch  20: f-est =  5.090845e+03, fit =  8.030e-01, step =  1.0e-02, time = 1.54e-01 sec
# Updating spatial modes...
# Initial f-est:  5.249910e+03, fit:  8.030e-01, tensor norm:  3.644e+02
# Epoch   1: f-est =  5.255336e+03, fit =  8.032e-01, step =  1.0e-04, time = 1.25e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   2: f-est =  5.249145e+03, fit =  8.031e-01, step =  1.0e-05, time = 2.40e-02 sec
# Epoch   3: f-est =  5.247177e+03, fit =  8.031e-01, step =  1.0e-05, time = 3.50e-02 sec
# Epoch   4: f-est =  5.245378e+03, fit =  8.032e-01, step =  1.0e-05, time = 4.60e-02 sec
# Epoch   5: f-est =  5.243832e+03, fit =  8.032e-01, step =  1.0e-05, time = 5.74e-02 sec
#
# Processing slice 80 of 190
# Solving for temporal mode...
# Initial f-est:  1.406226e+04, fit:  7.286e-01, tensor norm:  4.371e+02
# Epoch   1: f-est =  9.381149e+03, fit =  7.805e-01, step =  1.0e+01, time = 6.78e-03 sec
# Epoch   2: f-est =  7.827129e+03, fit =  8.001e-01, step =  1.0e+01, time = 1.35e-02 sec
# Epoch   3: f-est =  7.756553e+03, fit =  8.012e-01, step =  1.0e+01, time = 1.97e-02 sec
# Epoch   4: f-est =  7.652646e+03, fit =  8.021e-01, step =  1.0e+01, time = 2.66e-02 sec
# Epoch   5: f-est =  7.631815e+03, fit =  8.022e-01, step =  1.0e+01, time = 3.31e-02 sec
# Epoch   6: f-est =  7.590862e+03, fit =  8.030e-01, step =  1.0e+01, time = 3.96e-02 sec
# Epoch   7: f-est =  7.573612e+03, fit =  8.032e-01, step =  1.0e+01, time = 4.60e-02 sec
# Epoch   8: f-est =  7.569123e+03, fit =  8.031e-01, step =  1.0e+01, time = 5.27e-02 sec
# Epoch   9: f-est =  7.566426e+03, fit =  8.032e-01, step =  1.0e+01, time = 5.94e-02 sec
# Epoch  10: f-est =  7.597182e+03, fit =  8.031e-01, step =  1.0e+01, time = 6.59e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch  11: f-est =  7.559307e+03, fit =  8.033e-01, step =  1.0e+00, time = 7.22e-02 sec
# Epoch  12: f-est =  7.558167e+03, fit =  8.034e-01, step =  1.0e+00, time = 7.88e-02 sec
# Epoch  13: f-est =  7.554888e+03, fit =  8.035e-01, step =  1.0e+00, time = 8.49e-02 sec
# Epoch  14: f-est =  7.553371e+03, fit =  8.035e-01, step =  1.0e+00, time = 9.17e-02 sec
# Epoch  15: f-est =  7.558136e+03, fit =  8.035e-01, step =  1.0e+00, time = 9.79e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  16: f-est =  7.553223e+03, fit =  8.035e-01, step =  1.0e-01, time = 1.04e-01 sec
# Epoch  17: f-est =  7.553273e+03, fit =  8.035e-01, step =  1.0e-01, time = 1.11e-01 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  18: f-est =  7.553162e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.17e-01 sec
# Epoch  19: f-est =  7.553078e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.23e-01 sec
# Epoch  20: f-est =  7.553007e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.30e-01 sec
# Updating spatial modes...
# Initial f-est:  7.426608e+03, fit:  8.035e-01, tensor norm:  4.371e+02
# Epoch   1: f-est =  7.432133e+03, fit =  8.037e-01, step =  1.0e-04, time = 1.28e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   2: f-est =  7.425055e+03, fit =  8.035e-01, step =  1.0e-05, time = 2.35e-02 sec
# Epoch   3: f-est =  7.422789e+03, fit =  8.036e-01, step =  1.0e-05, time = 3.50e-02 sec
# Epoch   4: f-est =  7.421148e+03, fit =  8.036e-01, step =  1.0e-05, time = 4.65e-02 sec
# Epoch   5: f-est =  7.419753e+03, fit =  8.036e-01, step =  1.0e-05, time = 5.76e-02 sec
#
# Processing slice 90 of 190
# Solving for temporal mode...
# Initial f-est:  1.093153e+04, fit:  6.899e-01, tensor norm:  3.352e+02
# Epoch   1: f-est =  5.760138e+03, fit =  7.717e-01, step =  1.0e+01, time = 8.26e-03 sec
# Epoch   2: f-est =  4.537661e+03, fit =  7.975e-01, step =  1.0e+01, time = 1.63e-02 sec
# Epoch   3: f-est =  4.465705e+03, fit =  7.994e-01, step =  1.0e+01, time = 2.42e-02 sec
# Epoch   4: f-est =  4.394286e+03, fit =  8.011e-01, step =  1.0e+01, time = 3.20e-02 sec
# Epoch   5: f-est =  4.350532e+03, fit =  8.019e-01, step =  1.0e+01, time = 3.95e-02 sec
# Epoch   6: f-est =  4.319721e+03, fit =  8.024e-01, step =  1.0e+01, time = 4.70e-02 sec
# Epoch   7: f-est =  4.339630e+03, fit =  8.023e-01, step =  1.0e+01, time = 5.47e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   8: f-est =  4.312406e+03, fit =  8.028e-01, step =  1.0e+00, time = 6.26e-02 sec
# Epoch   9: f-est =  4.305074e+03, fit =  8.030e-01, step =  1.0e+00, time = 7.05e-02 sec
# Epoch  10: f-est =  4.300044e+03, fit =  8.030e-01, step =  1.0e+00, time = 7.82e-02 sec
# Epoch  11: f-est =  4.300411e+03, fit =  8.031e-01, step =  1.0e+00, time = 8.58e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  12: f-est =  4.298465e+03, fit =  8.030e-01, step =  1.0e-01, time = 9.34e-02 sec
# Epoch  13: f-est =  4.299059e+03, fit =  8.031e-01, step =  1.0e-01, time = 1.01e-01 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  14: f-est =  4.298406e+03, fit =  8.031e-01, step =  1.0e-02, time = 1.08e-01 sec
# Epoch  15: f-est =  4.298399e+03, fit =  8.031e-01, step =  1.0e-02, time = 1.16e-01 sec
# Epoch  16: f-est =  4.298419e+03, fit =  8.031e-01, step =  1.0e-02, time = 1.24e-01 sec, nfails = 4 (resetting to solution from last epoch)
# Updating spatial modes...
# Initial f-est:  4.407754e+03, fit:  8.031e-01, tensor norm:  3.352e+02
# Epoch   1: f-est =  4.410817e+03, fit =  8.032e-01, step =  1.0e-04, time = 1.34e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   2: f-est =  4.407348e+03, fit =  8.031e-01, step =  1.0e-05, time = 2.43e-02 sec
# Epoch   3: f-est =  4.406376e+03, fit =  8.031e-01, step =  1.0e-05, time = 3.59e-02 sec
# Epoch   4: f-est =  4.405380e+03, fit =  8.031e-01, step =  1.0e-05, time = 4.71e-02 sec
# Epoch   5: f-est =  4.404476e+03, fit =  8.032e-01, step =  1.0e-05, time = 5.80e-02 sec
#
# Processing slice 100 of 190
# Solving for temporal mode...
# Initial f-est:  2.153496e+04, fit:  6.348e-01, tensor norm:  3.992e+02
# Epoch   1: f-est =  7.579415e+03, fit =  7.827e-01, step =  1.0e+01, time = 8.44e-03 sec
# Epoch   2: f-est =  6.402733e+03, fit =  8.008e-01, step =  1.0e+01, time = 1.63e-02 sec
# Epoch   3: f-est =  6.423545e+03, fit =  8.010e-01, step =  1.0e+01, time = 2.38e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   4: f-est =  6.346030e+03, fit =  8.017e-01, step =  1.0e+00, time = 3.15e-02 sec
# Epoch   5: f-est =  6.339332e+03, fit =  8.023e-01, step =  1.0e+00, time = 3.90e-02 sec
# Epoch   6: f-est =  6.292128e+03, fit =  8.029e-01, step =  1.0e+00, time = 4.68e-02 sec
# Epoch   7: f-est =  6.271791e+03, fit =  8.032e-01, step =  1.0e+00, time = 5.38e-02 sec
# Epoch   8: f-est =  6.270801e+03, fit =  8.033e-01, step =  1.0e+00, time = 6.19e-02 sec
# Epoch   9: f-est =  6.260495e+03, fit =  8.035e-01, step =  1.0e+00, time = 6.91e-02 sec
# Epoch  10: f-est =  6.258595e+03, fit =  8.035e-01, step =  1.0e+00, time = 9.49e-02 sec
# Epoch  11: f-est =  6.256725e+03, fit =  8.035e-01, step =  1.0e+00, time = 1.05e-01 sec
# Epoch  12: f-est =  6.262004e+03, fit =  8.035e-01, step =  1.0e+00, time = 1.12e-01 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  13: f-est =  6.256821e+03, fit =  8.035e-01, step =  1.0e-01, time = 1.20e-01 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  14: f-est =  6.256695e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.28e-01 sec
# Epoch  15: f-est =  6.256629e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.35e-01 sec
# Epoch  16: f-est =  6.256538e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.43e-01 sec
# Epoch  17: f-est =  6.256465e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.50e-01 sec
# Epoch  18: f-est =  6.256466e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.58e-01 sec, nfails = 4 (resetting to solution from last epoch)
# Updating spatial modes...
# Initial f-est:  6.064502e+03, fit:  8.035e-01, tensor norm:  3.992e+02
# Epoch   1: f-est =  6.071832e+03, fit =  8.037e-01, step =  1.0e-04, time = 1.28e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   2: f-est =  6.063724e+03, fit =  8.036e-01, step =  1.0e-05, time = 2.43e-02 sec
# Epoch   3: f-est =  6.061419e+03, fit =  8.036e-01, step =  1.0e-05, time = 3.56e-02 sec
# Epoch   4: f-est =  6.059835e+03, fit =  8.036e-01, step =  1.0e-05, time = 4.71e-02 sec
# Epoch   5: f-est =  6.058138e+03, fit =  8.037e-01, step =  1.0e-05, time = 5.83e-02 sec
#
# Processing slice 110 of 190
# Solving for temporal mode...
# Initial f-est:  2.772332e+04, fit:  6.423e-01, tensor norm:  4.640e+02
# Epoch   1: f-est =  1.072016e+04, fit =  7.771e-01, step =  1.0e+01, time = 7.16e-03 sec
# Epoch   2: f-est =  8.331122e+03, fit =  8.020e-01, step =  1.0e+01, time = 1.39e-02 sec
# Epoch   3: f-est =  8.660011e+03, fit =  7.988e-01, step =  1.0e+01, time = 2.00e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   4: f-est =  8.334617e+03, fit =  8.020e-01, step =  1.0e+00, time = 2.73e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch   5: f-est =  8.324924e+03, fit =  8.021e-01, step =  1.0e-01, time = 3.34e-02 sec
# Epoch   6: f-est =  8.317399e+03, fit =  8.022e-01, step =  1.0e-01, time = 4.03e-02 sec
# Epoch   7: f-est =  8.310382e+03, fit =  8.023e-01, step =  1.0e-01, time = 4.66e-02 sec
# Epoch   8: f-est =  8.304801e+03, fit =  8.025e-01, step =  1.0e-01, time = 5.32e-02 sec
# Epoch   9: f-est =  8.300539e+03, fit =  8.026e-01, step =  1.0e-01, time = 5.97e-02 sec
# Epoch  10: f-est =  8.297630e+03, fit =  8.027e-01, step =  1.0e-01, time = 6.64e-02 sec
# Epoch  11: f-est =  8.294728e+03, fit =  8.027e-01, step =  1.0e-01, time = 7.31e-02 sec
# Epoch  12: f-est =  8.291645e+03, fit =  8.028e-01, step =  1.0e-01, time = 7.97e-02 sec
# Epoch  13: f-est =  8.287994e+03, fit =  8.028e-01, step =  1.0e-01, time = 8.60e-02 sec
# Epoch  14: f-est =  8.285120e+03, fit =  8.029e-01, step =  1.0e-01, time = 9.28e-02 sec
# Epoch  15: f-est =  8.281767e+03, fit =  8.029e-01, step =  1.0e-01, time = 9.91e-02 sec
# Epoch  16: f-est =  8.278467e+03, fit =  8.030e-01, step =  1.0e-01, time = 1.06e-01 sec
# Epoch  17: f-est =  8.275766e+03, fit =  8.030e-01, step =  1.0e-01, time = 1.12e-01 sec
# Epoch  18: f-est =  8.274223e+03, fit =  8.031e-01, step =  1.0e-01, time = 1.19e-01 sec
# Epoch  19: f-est =  8.271491e+03, fit =  8.031e-01, step =  1.0e-01, time = 1.26e-01 sec
# Epoch  20: f-est =  8.269178e+03, fit =  8.031e-01, step =  1.0e-01, time = 1.32e-01 sec
# Updating spatial modes...
# Initial f-est:  8.415735e+03, fit:  8.031e-01, tensor norm:  4.640e+02
# Epoch   1: f-est =  8.411563e+03, fit =  8.034e-01, step =  1.0e-04, time = 1.28e-02 sec
# Epoch   2: f-est =  8.406632e+03, fit =  8.037e-01, step =  1.0e-04, time = 2.41e-02 sec
# Epoch   3: f-est =  8.402033e+03, fit =  8.038e-01, step =  1.0e-04, time = 3.51e-02 sec
# Epoch   4: f-est =  8.401231e+03, fit =  8.038e-01, step =  1.0e-04, time = 4.62e-02 sec
# Epoch   5: f-est =  8.400459e+03, fit =  8.039e-01, step =  1.0e-04, time = 5.78e-02 sec
#
# Processing slice 120 of 190
# Solving for temporal mode...
# Initial f-est:  1.325319e+04, fit:  6.528e-01, tensor norm:  3.336e+02
# Epoch   1: f-est =  5.996184e+03, fit =  7.670e-01, step =  1.0e+01, time = 7.79e-03 sec
# Epoch   2: f-est =  4.660177e+03, fit =  7.952e-01, step =  1.0e+01, time = 1.68e-02 sec
# Epoch   3: f-est =  4.452587e+03, fit =  7.997e-01, step =  1.0e+01, time = 2.40e-02 sec
# Epoch   4: f-est =  4.456087e+03, fit =  7.993e-01, step =  1.0e+01, time = 3.17e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   5: f-est =  4.410461e+03, fit =  8.007e-01, step =  1.0e+00, time = 3.89e-02 sec
# Epoch   6: f-est =  4.365894e+03, fit =  8.016e-01, step =  1.0e+00, time = 4.69e-02 sec
# Epoch   7: f-est =  4.333574e+03, fit =  8.023e-01, step =  1.0e+00, time = 5.42e-02 sec
# Epoch   8: f-est =  4.310413e+03, fit =  8.027e-01, step =  1.0e+00, time = 6.17e-02 sec
# Epoch   9: f-est =  4.298720e+03, fit =  8.030e-01, step =  1.0e+00, time = 6.94e-02 sec
# Epoch  10: f-est =  4.292998e+03, fit =  8.031e-01, step =  1.0e+00, time = 7.67e-02 sec
# Epoch  11: f-est =  4.288470e+03, fit =  8.032e-01, step =  1.0e+00, time = 8.43e-02 sec
# Epoch  12: f-est =  4.292770e+03, fit =  8.032e-01, step =  1.0e+00, time = 9.17e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  13: f-est =  4.288482e+03, fit =  8.032e-01, step =  1.0e-01, time = 9.95e-02 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  14: f-est =  4.288447e+03, fit =  8.032e-01, step =  1.0e-02, time = 1.07e-01 sec
# Epoch  15: f-est =  4.288396e+03, fit =  8.032e-01, step =  1.0e-02, time = 1.14e-01 sec
# Epoch  16: f-est =  4.288325e+03, fit =  8.032e-01, step =  1.0e-02, time = 1.22e-01 sec
# Epoch  17: f-est =  4.288281e+03, fit =  8.032e-01, step =  1.0e-02, time = 1.30e-01 sec
# Epoch  18: f-est =  4.288216e+03, fit =  8.032e-01, step =  1.0e-02, time = 1.37e-01 sec
# Epoch  19: f-est =  4.288150e+03, fit =  8.032e-01, step =  1.0e-02, time = 1.44e-01 sec
# Epoch  20: f-est =  4.288113e+03, fit =  8.032e-01, step =  1.0e-02, time = 1.52e-01 sec
# Updating spatial modes...
# Initial f-est:  4.307745e+03, fit:  8.032e-01, tensor norm:  3.336e+02
# Epoch   1: f-est =  4.310043e+03, fit =  8.034e-01, step =  1.0e-04, time = 1.26e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   2: f-est =  4.307027e+03, fit =  8.033e-01, step =  1.0e-05, time = 2.34e-02 sec
# Epoch   3: f-est =  4.305575e+03, fit =  8.033e-01, step =  1.0e-05, time = 3.46e-02 sec
# Epoch   4: f-est =  4.304214e+03, fit =  8.033e-01, step =  1.0e-05, time = 4.52e-02 sec
# Epoch   5: f-est =  4.303414e+03, fit =  8.034e-01, step =  1.0e-05, time = 5.66e-02 sec
#
# Processing slice 130 of 190
# Solving for temporal mode...
# Initial f-est:  1.149403e+04, fit:  7.338e-01, tensor norm:  4.034e+02
# Epoch   1: f-est =  6.696423e+03, fit =  7.963e-01, step =  1.0e+01, time = 8.11e-03 sec
# Epoch   2: f-est =  6.420719e+03, fit =  8.004e-01, step =  1.0e+01, time = 1.63e-02 sec
# Epoch   3: f-est =  6.368995e+03, fit =  8.010e-01, step =  1.0e+01, time = 2.38e-02 sec
# Epoch   4: f-est =  6.357903e+03, fit =  8.013e-01, step =  1.0e+01, time = 3.15e-02 sec
# Epoch   5: f-est =  6.265224e+03, fit =  8.028e-01, step =  1.0e+01, time = 3.90e-02 sec
# Epoch   6: f-est =  6.314506e+03, fit =  8.023e-01, step =  1.0e+01, time = 4.67e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   7: f-est =  6.241048e+03, fit =  8.032e-01, step =  1.0e+00, time = 5.43e-02 sec
# Epoch   8: f-est =  6.238029e+03, fit =  8.032e-01, step =  1.0e+00, time = 6.21e-02 sec
# Epoch   9: f-est =  6.235264e+03, fit =  8.033e-01, step =  1.0e+00, time = 6.99e-02 sec
# Epoch  10: f-est =  6.229761e+03, fit =  8.034e-01, step =  1.0e+00, time = 7.76e-02 sec
# Epoch  11: f-est =  6.232957e+03, fit =  8.033e-01, step =  1.0e+00, time = 8.55e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  12: f-est =  6.229103e+03, fit =  8.034e-01, step =  1.0e-01, time = 9.36e-02 sec
# Epoch  13: f-est =  6.228648e+03, fit =  8.034e-01, step =  1.0e-01, time = 1.01e-01 sec
# Epoch  14: f-est =  6.228479e+03, fit =  8.034e-01, step =  1.0e-01, time = 1.09e-01 sec
# Epoch  15: f-est =  6.228475e+03, fit =  8.034e-01, step =  1.0e-01, time = 1.17e-01 sec
# Epoch  16: f-est =  6.228619e+03, fit =  8.034e-01, step =  1.0e-01, time = 1.25e-01 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  17: f-est =  6.228449e+03, fit =  8.034e-01, step =  1.0e-02, time = 1.33e-01 sec
# Epoch  18: f-est =  6.228385e+03, fit =  8.034e-01, step =  1.0e-02, time = 1.41e-01 sec
# Epoch  19: f-est =  6.228360e+03, fit =  8.034e-01, step =  1.0e-02, time = 1.48e-01 sec
# Epoch  20: f-est =  6.228382e+03, fit =  8.034e-01, step =  1.0e-02, time = 1.56e-01 sec, nfails = 4 (resetting to solution from last epoch)
# Updating spatial modes...
# Initial f-est:  6.445335e+03, fit:  8.034e-01, tensor norm:  4.034e+02
# Epoch   1: f-est =  6.444850e+03, fit =  8.036e-01, step =  1.0e-04, time = 1.33e-02 sec
# Epoch   2: f-est =  6.440018e+03, fit =  8.038e-01, step =  1.0e-04, time = 2.40e-02 sec
# Epoch   3: f-est =  6.436008e+03, fit =  8.039e-01, step =  1.0e-04, time = 3.55e-02 sec
# Epoch   4: f-est =  6.435174e+03, fit =  8.039e-01, step =  1.0e-04, time = 4.66e-02 sec
# Epoch   5: f-est =  6.435528e+03, fit =  8.039e-01, step =  1.0e-04, time = 5.82e-02 sec, nfails = 1 (resetting to solution from last epoch)
#
# Processing slice 140 of 190
# Solving for temporal mode...
# Initial f-est:  1.398697e+04, fit:  7.647e-01, tensor norm:  4.997e+02
# Epoch   1: f-est =  1.007529e+04, fit =  8.004e-01, step =  1.0e+01, time = 6.86e-03 sec
# Epoch   2: f-est =  1.028907e+04, fit =  7.984e-01, step =  1.0e+01, time = 1.75e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   3: f-est =  1.002781e+04, fit =  8.009e-01, step =  1.0e+00, time = 2.38e-02 sec
# Epoch   4: f-est =  9.922178e+03, fit =  8.018e-01, step =  1.0e+00, time = 3.06e-02 sec
# Epoch   5: f-est =  9.863097e+03, fit =  8.026e-01, step =  1.0e+00, time = 3.69e-02 sec
# Epoch   6: f-est =  9.815190e+03, fit =  8.030e-01, step =  1.0e+00, time = 4.34e-02 sec
# Epoch   7: f-est =  9.792738e+03, fit =  8.032e-01, step =  1.0e+00, time = 4.99e-02 sec
# Epoch   8: f-est =  9.797442e+03, fit =  8.032e-01, step =  1.0e+00, time = 5.65e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch   9: f-est =  9.788117e+03, fit =  8.032e-01, step =  1.0e-01, time = 6.31e-02 sec
# Epoch  10: f-est =  9.785361e+03, fit =  8.033e-01, step =  1.0e-01, time = 6.96e-02 sec
# Epoch  11: f-est =  9.785283e+03, fit =  8.033e-01, step =  1.0e-01, time = 7.58e-02 sec
# Epoch  12: f-est =  9.785025e+03, fit =  8.033e-01, step =  1.0e-01, time = 8.27e-02 sec
# Epoch  13: f-est =  9.783287e+03, fit =  8.033e-01, step =  1.0e-01, time = 8.89e-02 sec
# Epoch  14: f-est =  9.780816e+03, fit =  8.034e-01, step =  1.0e-01, time = 9.57e-02 sec
# Epoch  15: f-est =  9.778998e+03, fit =  8.034e-01, step =  1.0e-01, time = 1.02e-01 sec
# Epoch  16: f-est =  9.777534e+03, fit =  8.034e-01, step =  1.0e-01, time = 1.09e-01 sec
# Epoch  17: f-est =  9.776718e+03, fit =  8.034e-01, step =  1.0e-01, time = 1.15e-01 sec
# Epoch  18: f-est =  9.776298e+03, fit =  8.034e-01, step =  1.0e-01, time = 1.22e-01 sec
# Epoch  19: f-est =  9.774897e+03, fit =  8.034e-01, step =  1.0e-01, time = 1.28e-01 sec
# Epoch  20: f-est =  9.773851e+03, fit =  8.034e-01, step =  1.0e-01, time = 1.35e-01 sec
# Updating spatial modes...
# Initial f-est:  9.507577e+03, fit:  8.034e-01, tensor norm:  4.997e+02
# Epoch   1: f-est =  9.516147e+03, fit =  8.036e-01, step =  1.0e-04, time = 1.27e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   2: f-est =  9.505434e+03, fit =  8.035e-01, step =  1.0e-05, time = 2.36e-02 sec
# Epoch   3: f-est =  9.502755e+03, fit =  8.035e-01, step =  1.0e-05, time = 3.50e-02 sec
# Epoch   4: f-est =  9.500394e+03, fit =  8.035e-01, step =  1.0e-05, time = 4.62e-02 sec
# Epoch   5: f-est =  9.498138e+03, fit =  8.036e-01, step =  1.0e-05, time = 5.72e-02 sec
#
# Processing slice 150 of 190
# Solving for temporal mode...
# Initial f-est:  1.464158e+04, fit:  5.872e-01, tensor norm:  2.933e+02
# Epoch   1: f-est =  5.643040e+03, fit =  7.423e-01, step =  1.0e+01, time = 7.97e-03 sec
# Epoch   2: f-est =  3.959097e+03, fit =  7.855e-01, step =  1.0e+01, time = 1.62e-02 sec
# Epoch   3: f-est =  3.589086e+03, fit =  7.961e-01, step =  1.0e+01, time = 2.38e-02 sec
# Epoch   4: f-est =  3.350976e+03, fit =  8.028e-01, step =  1.0e+01, time = 3.14e-02 sec
# Epoch   5: f-est =  3.356561e+03, fit =  8.028e-01, step =  1.0e+01, time = 3.90e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   6: f-est =  3.345947e+03, fit =  8.031e-01, step =  1.0e+00, time = 4.66e-02 sec
# Epoch   7: f-est =  3.343556e+03, fit =  8.033e-01, step =  1.0e+00, time = 5.43e-02 sec
# Epoch   8: f-est =  3.338041e+03, fit =  8.033e-01, step =  1.0e+00, time = 6.21e-02 sec
# Epoch   9: f-est =  3.336489e+03, fit =  8.034e-01, step =  1.0e+00, time = 6.94e-02 sec
# Epoch  10: f-est =  3.339548e+03, fit =  8.034e-01, step =  1.0e+00, time = 7.75e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  11: f-est =  3.336432e+03, fit =  8.034e-01, step =  1.0e-01, time = 8.47e-02 sec
# Epoch  12: f-est =  3.336136e+03, fit =  8.034e-01, step =  1.0e-01, time = 9.24e-02 sec
# Epoch  13: f-est =  3.336432e+03, fit =  8.034e-01, step =  1.0e-01, time = 9.96e-02 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  14: f-est =  3.336134e+03, fit =  8.034e-01, step =  1.0e-02, time = 1.07e-01 sec
# Epoch  15: f-est =  3.336100e+03, fit =  8.034e-01, step =  1.0e-02, time = 1.15e-01 sec
# Epoch  16: f-est =  3.336055e+03, fit =  8.034e-01, step =  1.0e-02, time = 1.23e-01 sec
# Epoch  17: f-est =  3.335985e+03, fit =  8.034e-01, step =  1.0e-02, time = 1.30e-01 sec
# Epoch  18: f-est =  3.335935e+03, fit =  8.034e-01, step =  1.0e-02, time = 1.38e-01 sec
# Epoch  19: f-est =  3.335915e+03, fit =  8.034e-01, step =  1.0e-02, time = 1.66e-01 sec
# Epoch  20: f-est =  3.335893e+03, fit =  8.034e-01, step =  1.0e-02, time = 1.74e-01 sec
# Updating spatial modes...
# Initial f-est:  3.294709e+03, fit:  8.034e-01, tensor norm:  2.933e+02
# Epoch   1: f-est =  3.299282e+03, fit =  8.035e-01, step =  1.0e-04, time = 1.32e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   2: f-est =  3.294512e+03, fit =  8.034e-01, step =  1.0e-05, time = 2.45e-02 sec
# Epoch   3: f-est =  3.294031e+03, fit =  8.035e-01, step =  1.0e-05, time = 3.61e-02 sec
# Epoch   4: f-est =  3.293465e+03, fit =  8.035e-01, step =  1.0e-05, time = 4.75e-02 sec
# Epoch   5: f-est =  3.293012e+03, fit =  8.035e-01, step =  1.0e-05, time = 5.86e-02 sec
#
# Processing slice 160 of 190
# Solving for temporal mode...
# Initial f-est:  8.554575e+03, fit:  7.275e-01, tensor norm:  3.408e+02
# Epoch   1: f-est =  5.406623e+03, fit =  7.867e-01, step =  1.0e+01, time = 6.94e-03 sec
# Epoch   2: f-est =  4.716420e+03, fit =  7.998e-01, step =  1.0e+01, time = 1.38e-02 sec
# Epoch   3: f-est =  4.708046e+03, fit =  8.000e-01, step =  1.0e+01, time = 2.07e-02 sec
# Epoch   4: f-est =  4.663715e+03, fit =  8.013e-01, step =  1.0e+01, time = 2.75e-02 sec
# Epoch   5: f-est =  4.583025e+03, fit =  8.032e-01, step =  1.0e+01, time = 3.41e-02 sec
# Epoch   6: f-est =  4.586577e+03, fit =  8.032e-01, step =  1.0e+01, time = 4.09e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   7: f-est =  4.575004e+03, fit =  8.034e-01, step =  1.0e+00, time = 4.73e-02 sec
# Epoch   8: f-est =  4.568570e+03, fit =  8.034e-01, step =  1.0e+00, time = 5.40e-02 sec
# Epoch   9: f-est =  4.563405e+03, fit =  8.035e-01, step =  1.0e+00, time = 6.03e-02 sec
# Epoch  10: f-est =  4.562415e+03, fit =  8.036e-01, step =  1.0e+00, time = 6.70e-02 sec
# Epoch  11: f-est =  4.563864e+03, fit =  8.036e-01, step =  1.0e+00, time = 7.33e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  12: f-est =  4.562772e+03, fit =  8.036e-01, step =  1.0e-01, time = 7.98e-02 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  13: f-est =  4.562384e+03, fit =  8.036e-01, step =  1.0e-02, time = 8.65e-02 sec
# Epoch  14: f-est =  4.562371e+03, fit =  8.036e-01, step =  1.0e-02, time = 9.33e-02 sec
# Epoch  15: f-est =  4.562350e+03, fit =  8.036e-01, step =  1.0e-02, time = 1.00e-01 sec
# Epoch  16: f-est =  4.562353e+03, fit =  8.036e-01, step =  1.0e-02, time = 1.07e-01 sec, nfails = 4 (resetting to solution from last epoch)
# Updating spatial modes...
# Initial f-est:  4.531818e+03, fit:  8.036e-01, tensor norm:  3.408e+02
# Epoch   1: f-est =  4.534126e+03, fit =  8.037e-01, step =  1.0e-04, time = 1.30e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   2: f-est =  4.531290e+03, fit =  8.036e-01, step =  1.0e-05, time = 2.41e-02 sec
# Epoch   3: f-est =  4.530322e+03, fit =  8.036e-01, step =  1.0e-05, time = 3.54e-02 sec
# Epoch   4: f-est =  4.529311e+03, fit =  8.036e-01, step =  1.0e-05, time = 4.69e-02 sec
# Epoch   5: f-est =  4.528862e+03, fit =  8.036e-01, step =  1.0e-05, time = 5.81e-02 sec
#
# Processing slice 170 of 190
# Solving for temporal mode...
# Initial f-est:  1.479815e+04, fit:  7.070e-01, tensor norm:  4.099e+02
# Epoch   1: f-est =  7.072930e+03, fit =  7.963e-01, step =  1.0e+01, time = 6.92e-03 sec
# Epoch   2: f-est =  7.044776e+03, fit =  7.965e-01, step =  1.0e+01, time = 1.38e-02 sec
# Epoch   3: f-est =  6.684646e+03, fit =  8.014e-01, step =  1.0e+01, time = 1.98e-02 sec
# Epoch   4: f-est =  6.701679e+03, fit =  8.022e-01, step =  1.0e+01, time = 2.62e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   5: f-est =  6.680077e+03, fit =  8.022e-01, step =  1.0e+00, time = 3.58e-02 sec
# Epoch   6: f-est =  6.617681e+03, fit =  8.028e-01, step =  1.0e+00, time = 4.24e-02 sec
# Epoch   7: f-est =  6.607771e+03, fit =  8.033e-01, step =  1.0e+00, time = 4.89e-02 sec
# Epoch   8: f-est =  6.597708e+03, fit =  8.033e-01, step =  1.0e+00, time = 5.56e-02 sec
# Epoch   9: f-est =  6.600387e+03, fit =  8.034e-01, step =  1.0e+00, time = 6.22e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  10: f-est =  6.597398e+03, fit =  8.034e-01, step =  1.0e-01, time = 6.85e-02 sec
# Epoch  11: f-est =  6.598792e+03, fit =  8.034e-01, step =  1.0e-01, time = 7.46e-02 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  12: f-est =  6.597344e+03, fit =  8.034e-01, step =  1.0e-02, time = 8.16e-02 sec
# Epoch  13: f-est =  6.597335e+03, fit =  8.034e-01, step =  1.0e-02, time = 8.75e-02 sec
# Epoch  14: f-est =  6.597401e+03, fit =  8.034e-01, step =  1.0e-02, time = 9.43e-02 sec, nfails = 4 (resetting to solution from last epoch)
# Updating spatial modes...
# Initial f-est:  6.482043e+03, fit:  8.034e-01, tensor norm:  4.099e+02
# Epoch   1: f-est =  6.485740e+03, fit =  8.036e-01, step =  1.0e-04, time = 1.26e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   2: f-est =  6.480936e+03, fit =  8.034e-01, step =  1.0e-05, time = 2.40e-02 sec
# Epoch   3: f-est =  6.479242e+03, fit =  8.035e-01, step =  1.0e-05, time = 3.53e-02 sec
# Epoch   4: f-est =  6.477432e+03, fit =  8.035e-01, step =  1.0e-05, time = 4.62e-02 sec
# Epoch   5: f-est =  6.476076e+03, fit =  8.036e-01, step =  1.0e-05, time = 5.73e-02 sec
#
# Processing slice 180 of 190
# Solving for temporal mode...
# Initial f-est:  1.767293e+04, fit:  6.306e-01, tensor norm:  3.603e+02
# Epoch   1: f-est =  6.881521e+03, fit =  7.693e-01, step =  1.0e+01, time = 6.97e-03 sec
# Epoch   2: f-est =  5.713556e+03, fit =  7.903e-01, step =  1.0e+01, time = 1.39e-02 sec
# Epoch   3: f-est =  5.385981e+03, fit =  7.965e-01, step =  1.0e+01, time = 2.03e-02 sec
# Epoch   4: f-est =  5.083782e+03, fit =  8.026e-01, step =  1.0e+01, time = 2.71e-02 sec
# Epoch   5: f-est =  5.121731e+03, fit =  8.020e-01, step =  1.0e+01, time = 3.37e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   6: f-est =  5.073531e+03, fit =  8.029e-01, step =  1.0e+00, time = 4.03e-02 sec
# Epoch   7: f-est =  5.070173e+03, fit =  8.030e-01, step =  1.0e+00, time = 4.65e-02 sec
# Epoch   8: f-est =  5.064040e+03, fit =  8.031e-01, step =  1.0e+00, time = 5.41e-02 sec
# Epoch   9: f-est =  5.062002e+03, fit =  8.031e-01, step =  1.0e+00, time = 6.03e-02 sec
# Epoch  10: f-est =  5.057977e+03, fit =  8.031e-01, step =  1.0e+00, time = 6.73e-02 sec
# Epoch  11: f-est =  5.055459e+03, fit =  8.032e-01, step =  1.0e+00, time = 7.38e-02 sec
# Epoch  12: f-est =  5.051270e+03, fit =  8.031e-01, step =  1.0e+00, time = 8.03e-02 sec
# Epoch  13: f-est =  5.052460e+03, fit =  8.032e-01, step =  1.0e+00, time = 8.69e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  14: f-est =  5.051111e+03, fit =  8.032e-01, step =  1.0e-01, time = 9.35e-02 sec
# Epoch  15: f-est =  5.051179e+03, fit =  8.032e-01, step =  1.0e-01, time = 1.00e-01 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  16: f-est =  5.051118e+03, fit =  8.032e-01, step =  1.0e-02, time = 1.07e-01 sec, nfails = 4 (resetting to solution from last epoch)
# Updating spatial modes...
# Initial f-est:  4.973938e+03, fit:  8.032e-01, tensor norm:  3.603e+02
# Epoch   1: f-est =  4.977316e+03, fit =  8.033e-01, step =  1.0e-04, time = 1.30e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   2: f-est =  4.973259e+03, fit =  8.032e-01, step =  1.0e-05, time = 2.42e-02 sec
# Epoch   3: f-est =  4.971833e+03, fit =  8.032e-01, step =  1.0e-05, time = 3.52e-02 sec
# Epoch   4: f-est =  4.970249e+03, fit =  8.033e-01, step =  1.0e-05, time = 4.68e-02 sec
# Epoch   5: f-est =  4.969066e+03, fit =  8.033e-01, step =  1.0e-05, time = 5.78e-02 sec
#
# Processing slice 190 of 190
# Solving for temporal mode...
# Initial f-est:  1.929095e+04, fit:  5.581e-01, tensor norm:  3.154e+02
# Epoch   1: f-est =  6.148414e+03, fit =  7.516e-01, step =  1.0e+01, time = 6.88e-03 sec
# Epoch   2: f-est =  4.446158e+03, fit =  7.894e-01, step =  1.0e+01, time = 1.35e-02 sec
# Epoch   3: f-est =  4.317960e+03, fit =  7.927e-01, step =  1.0e+01, time = 2.00e-02 sec
# Epoch   4: f-est =  3.952830e+03, fit =  8.012e-01, step =  1.0e+01, time = 2.68e-02 sec
# Epoch   5: f-est =  3.904957e+03, fit =  8.023e-01, step =  1.0e+01, time = 3.31e-02 sec
# Epoch   6: f-est =  3.915267e+03, fit =  8.023e-01, step =  1.0e+01, time = 3.99e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   7: f-est =  3.895946e+03, fit =  8.026e-01, step =  1.0e+00, time = 4.61e-02 sec
# Epoch   8: f-est =  3.883431e+03, fit =  8.029e-01, step =  1.0e+00, time = 5.28e-02 sec
# Epoch   9: f-est =  3.879002e+03, fit =  8.031e-01, step =  1.0e+00, time = 5.93e-02 sec
# Epoch  10: f-est =  3.872428e+03, fit =  8.033e-01, step =  1.0e+00, time = 6.57e-02 sec
# Epoch  11: f-est =  3.869802e+03, fit =  8.034e-01, step =  1.0e+00, time = 7.22e-02 sec
# Epoch  12: f-est =  3.865075e+03, fit =  8.035e-01, step =  1.0e+00, time = 7.88e-02 sec
# Epoch  13: f-est =  3.864492e+03, fit =  8.034e-01, step =  1.0e+00, time = 8.49e-02 sec
# Epoch  14: f-est =  3.862018e+03, fit =  8.035e-01, step =  1.0e+00, time = 9.17e-02 sec
# Epoch  15: f-est =  3.862062e+03, fit =  8.035e-01, step =  1.0e+00, time = 9.78e-02 sec, nfails = 2 (resetting to solution from last epoch)
# Epoch  16: f-est =  3.862052e+03, fit =  8.035e-01, step =  1.0e-01, time = 1.05e-01 sec, nfails = 3 (resetting to solution from last epoch)
# Epoch  17: f-est =  3.862004e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.11e-01 sec
# Epoch  18: f-est =  3.861978e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.17e-01 sec
# Epoch  19: f-est =  3.861950e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.24e-01 sec
# Epoch  20: f-est =  3.861927e+03, fit =  8.035e-01, step =  1.0e-02, time = 1.31e-01 sec
# Updating spatial modes...
# Initial f-est:  3.879267e+03, fit:  8.035e-01, tensor norm:  3.154e+02
# Epoch   1: f-est =  3.883043e+03, fit =  8.037e-01, step =  1.0e-04, time = 1.28e-02 sec, nfails = 1 (resetting to solution from last epoch)
# Epoch   2: f-est =  3.878796e+03, fit =  8.035e-01, step =  1.0e-05, time = 2.42e-02 sec
# Epoch   3: f-est =  3.877867e+03, fit =  8.036e-01, step =  1.0e-05, time = 3.54e-02 sec
# Epoch   4: f-est =  3.876942e+03, fit =  8.036e-01, step =  1.0e-05, time = 4.66e-02 sec
# Epoch   5: f-est =  3.876244e+03, fit =  8.036e-01, step =  1.0e-05, time = 5.77e-02 sec
# np.float64(0.8064107220878872)

# %% [markdown]
# ### Plot the local and global reconstruction (Gaussian) loss as well as the similarity score with the true underlying k-tensor
# Local loss is the loss computed for each time slice using the factor matrices as they were after each streaming step.  Global loss is the loss for each time slice using the factor matrices at the end of the computation.

# %%
# plot reconstruction errors and scores
fig, axs = plt.subplots(3,1)
axs[0].plot(reconstruction_cp_als, 'm+', label='Static CP-ALS')
axs[0].plot(reconstruction_static_gcp, 'ko', label='Static GCP', markerfacecolor='none')
axs[0].plot(local_reconstruction_gcp, 'bx', label='OnlineGCP', markerfacecolor='none')
axs[0].set_title('Local Normalized Loss')
axs[0].set_xlabel('Slice')
axs[0].set_ylabel('Normalized Loss')
axs[0].legend(loc='upper right')

axs[1].plot(reconstruction_cp_als, 'm+', label='Static CP-ALS')
axs[1].plot(reconstruction_static_gcp, 'ko', label='Static GCP', markerfacecolor='none')
axs[1].plot(global_reconstruction_gcp, 'bx', label='OnlineGCP', markerfacecolor='none')
axs[1].set_title('Global Normalized Loss')
axs[1].set_xlabel('Slice')
axs[1].set_ylabel('Normalized Loss')
axs[1].legend(loc='upper right')

axs[2].plot(score_cp, 'm+', label='Static CP-ALS')
axs[2].plot(score_static_gcp, 'ko', label='Static GCP', markerfacecolor='none')
axs[2].plot(score_gcp, 'bx', label='OnlineGCP', markerfacecolor='none')
axs[2].set_title('K-tensor Score')
axs[2].set_xlabel('Slice')
axs[2].set_ylabel('Score')
axs[2].legend(loc='upper right')

fig.tight_layout()
